# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn.svm import SVC     ### SVM for classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression

from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import StackingClassifier

import random
import numpy as np
import math
from collections import Counter
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn import tree
import graphviz

# %%
from sklearn.tree import export_text

from IPython.display import Image  
from sklearn.tree import export_graphviz
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.svm import SVC
from datetime import datetime

# %%
def sap_xep_lai_cot():
    df = pd.read_csv('Leukemia_4c.csv', header = None ) 
    df.iloc[0,2000]
    cols = list(df.columns)
    c1=  cols[-1:]     ## lay phan tu cuoi cung cuar list
    c2 = cols[:-1]     ##  loai bo phan tu cuoi cung cuar list
    cols = cols[-1:] + cols[:-1]
    df = df[cols]
    df.columns.values[0] = "class"   # thay ten bang class
    
    ### Chuyen Dang Category thanh` 0-1;
    # Categorical boolean mask
    categorical_feature_mask = df.dtypes==object
   # filter categorical columns using mask and turn it into a list
    categorical_cols = df.columns[categorical_feature_mask].tolist()
    
    le = LabelEncoder()
    
    df[categorical_cols] = df[categorical_cols].apply(lambda col: le.fit_transform(col))
    df[categorical_cols].head(10)   
    df.to_csv('Leukemia_4c.csv', index= False)

# %%
def stratify_sampling(df):
    r,c = df.shape
    X = df.iloc[:,df.columns !='class']
    features = X.columns.tolist()
    y = df[['class']]

   # _random_state =  random.randint(0,100000)

    
    
  #  print (_random_state)
    acc_DT =list()
    acc_RF= list()
    
    for i in range (10):
        Train_x, Test_x, Train_y, Test_y = train_test_split(X, y, train_size=0.7)

        #Train_x, Test_x, Train_y, Test_y = train_test_split(X,  y, test_size=0.3, random_state = random.randint(0,100000))
        #Train_x, Test_x, Train_y, Test_y = train_test_split(X,  y, stratify=y, test_size=0.4, random_state = random.randint(0,100000))
        model = DecisionTreeClassifier()
        
        model.fit(Train_x, Train_y)
        
    
        predictions = model.predict(Test_x)
        print("Accuracy Cay Quyet Dinh:",metrics.accuracy_score(Test_y, predictions))
        acc_DT.append(metrics.accuracy_score(Test_y, predictions))

        rf_model = RandomForestClassifier(n_estimators=10, max_features= int(math.sqrt(c))+1)

        rf_model.fit(Train_x,Train_y.values.ravel())
        pred_y = rf_model.predict(Test_x)
        print("Accuracy RandomForest:",metrics.accuracy_score(Test_y, pred_y))
        acc_RF.append(metrics.accuracy_score(Test_y, pred_y))

        rf_model.bootstrap()[0]
       # print(metrics.confusion_matrix(Test_y,predictions))
       # print(metrics.classification_report(Test_y,predictions))
        #print(metrics.accuracy_score(Test_y, predictions))
    
    
    print ("Do Chinh Xac Trung Binh Cay quyet dinh: ", sum(acc_DT))
    print ("Do CHinh Xac Random forest: ", sum(acc_RF))
    return

# %%
def comparative(df):
    Y = df[['class']]
    X = df.iloc[:,df.columns !='class']
    r,c = df.shape
    acc_DT =list()
    acc_SVM =list()
    acc_Navie = list()
    acc_Bagging = list()
    acc_RF = list()

    time_DT =list()
    time_SVM =list()
    time_Naive =list()
    time_Bagging =list()
    time_RF =list()
    
    for i in range(100):
        print ("Chay Lan thu: ", i)

# split data
        X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y,  stratify=Y, train_size=0.7)
        
# decision tree        
        start = datetime.now()

        model = DecisionTreeClassifier()        
        model.fit(X_Train, Y_Train)            
        predictions = model.predict(X_Test)
        end = datetime.now() -start
        time_DT.append(end)

        print("Accuracy Cay Quyet Dinh:",metrics.accuracy_score(Y_Test, predictions))
        acc_DT.append(metrics.accuracy_score(Y_Test, predictions))
        

# SVM
#         start = datetime.now()

#         svclassifier = SVC(kernel='rbf')
#         svclassifier.fit(X_Train, Y_Train.values.ravel())
#         y_pred = svclassifier.predict(X_Test)
#         end = datetime.now() -start
#         time_SVM.append(end)

#         print("Accuracy SVM:",metrics.accuracy_score(Y_Test, y_pred))
#         acc_SVM.append(metrics.accuracy_score(Y_Test, y_pred))
        

# naive classifier
#         start = datetime.now()
#         model_navie = GaussianNB()
#       #  model_navie = MultinomialNB()        
#         model_navie.fit(X_Train, Y_Train.values.ravel()) 
#         prediction = model_navie.predict(X_Test) 
#         end = datetime.now() -start
#         time_Naive.append(end)
#         print("Naive Bayes: ", metrics.accuracy_score(Y_Test, prediction))
#         acc_Navie.append(metrics.accuracy_score(Y_Test, prediction))
       
    
# bagging
       #base_cls = SVC()
      # base_cls = KNeighborsClassifier(n_neighbors=5)
#         start = datetime.now()

#         base_cls = DecisionTreeClassifier()
        
#         #model = BaggingClassifier(base_estimator = base_cls, n_estimators = 100)
#         model_bagging = BaggingClassifier(base_estimator = base_cls, n_estimators = 1)
        
#         model_bagging.fit(X_Train, Y_Train.values.ravel())
#         predictions = model_bagging.predict(X_Test)
        
#         end = datetime.now() -start
#         time_Bagging.append(end)
                
#         acc = metrics.accuracy_score(Y_Test, predictions)    
#         acc_Bagging.append(acc)        
#         print ("Bagging: ",acc)     
        
        
#random forest
        start = datetime.now()

        rf_model = RandomForestClassifier(n_estimators=100, max_features= int(math.sqrt(c))+1)
        rf_model.fit(X_Train,Y_Train.values.ravel())
        pred_y = rf_model.predict(X_Test)
           
        end = datetime.now() -start
        time_RF.append(end)
                
        accRF = metrics.accuracy_score(Y_Test, pred_y)
        acc_RF.append(accRF)
        print ("Accuracy RF: ",accRF) 
    
        

    results =[]
    results.append(acc_DT)
#     results.append(acc_SVM)
#     results.append(acc_Navie)
#     results.append(acc_Bagging)
    results.append(acc_RF)
    # results.append(acc_RandomForest)
    # results.append(acc_Boosting)
    # results.append(acc_Stacking)


    #names =('decision tree','randomforest','boosting','stacking')
    names =('Decision tree','Random forest')
    fig = plt.figure()
    fig.suptitle('Algorithm Comparison')
    
   # ax = fig.add_subplot(111)
#    plt.boxplot(results)
    #plt.boxplot(results, labels=names, showmeans = True)
    plt.boxplot(results, labels=names)
    plt.ylabel('Accuracy')    

    #ax.set_xticklabels(names)
    plt.show()            
    
    print ("Results")
    print ("decision tree")
    print (np.mean(acc_DT))    ## gia tri trung binh  
    print (np.std(acc_DT))     ## Do lech chuan   
    
    
    print ("SVM")
    print (np.mean(acc_SVM))    ## gia tri trung binh  
    print (np.std(acc_SVM))     ## Do lech chuan   
    
    print ("Naive Bayes")
    print (np.mean(acc_Navie))    ## gia tri trung binh  
    print (np.std(acc_Navie))     ## Do lech chuan   
    
    print ("Bagging")
    print (np.mean(acc_Bagging))    ## gia tri trung binh  
    print (np.std(acc_Bagging))     ## Do lech chuan   
    
    print ("Random forest")
    print (np.mean(acc_RF))    ## gia tri trung binh  
    print (np.std(acc_RF))     ## Do lech chuan   
    
    print ("Time")
    print (np.mean(time_DT))
    print (np.mean(time_SVM))
    print (np.mean(time_Naive))
    print (np.mean(time_Bagging))
    print (np.mean(time_RF))

# %%
def load_data():
    
    x=2
    #Breast2classes
    df = pd.read_csv('CNS1.csv', header = 0 ) 
    r,c = df.shape
    df.columns.values[0] = "class" 
    
    comparative(df)

# %%
def main():
    x=1
    load_data()
    
    
if __name__ =="__main__":
    main()
# Out:
# Chay Lan thu:  0
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.3888888888888889
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  1
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.6666666666666666
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  2
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  3
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5
# Bagging:  0.5
# Accuracy RF:  0.7777777777777778
# Chay Lan thu:  4
# Accuracy Cay Quyet Dinh: 0.3333333333333333
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.5
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  5
# Accuracy Cay Quyet Dinh: 0.4444444444444444
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  6
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.8333333333333334
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  7
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.4444444444444444
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  8
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.8333333333333334
# Bagging:  0.6666666666666666
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  9
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  10
# Accuracy Cay Quyet Dinh: 0.2777777777777778
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.5
# Accuracy RF:  0.5555555555555556
# Chay Lan thu:  11
# Accuracy Cay Quyet Dinh: 0.3333333333333333
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.2777777777777778
# Accuracy RF:  0.4444444444444444
# Chay Lan thu:  12
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.3888888888888889
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  13
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.6666666666666666
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  14
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.4444444444444444
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  15
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.5555555555555556
# Accuracy RF:  0.7777777777777778
# Chay Lan thu:  16
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7777777777777778
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  17
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.6666666666666666
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  18
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.7222222222222222
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  19
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.8333333333333334
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  20
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.7222222222222222
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  21
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.5
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  22
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.6111111111111112
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  23
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.4444444444444444
# Accuracy RF:  0.5
# Chay Lan thu:  24
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.4444444444444444
# Bagging:  0.5555555555555556
# Accuracy RF:  0.2777777777777778
# Chay Lan thu:  25
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7777777777777778
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  26
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5
# Bagging:  0.5
# Accuracy RF:  0.5555555555555556
# Chay Lan thu:  27
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.3888888888888889
# Bagging:  0.6666666666666666
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  28
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.5
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  29
# Accuracy Cay Quyet Dinh: 0.3888888888888889
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5
# Bagging:  0.3888888888888889
# Accuracy RF:  0.5
# Chay Lan thu:  30
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.8888888888888888
# Bagging:  0.5
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  31
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  32
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.4444444444444444
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  33
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.3888888888888889
# Bagging:  0.5555555555555556
# Accuracy RF:  0.5555555555555556
# Chay Lan thu:  34
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.7222222222222222
# Accuracy RF:  0.5555555555555556
# Chay Lan thu:  35
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.8333333333333334
# Bagging:  0.5
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  36
# Accuracy Cay Quyet Dinh: 0.7777777777777778
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  37
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.4444444444444444
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  38
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  39
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.4444444444444444
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  40
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.7777777777777778
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  41
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.5555555555555556
# Accuracy RF:  0.5
# Chay Lan thu:  42
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.7222222222222222
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  43
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  44
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.7222222222222222
# Accuracy RF:  0.5
# Chay Lan thu:  45
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7777777777777778
# Bagging:  0.5
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  46
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.5
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  47
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7777777777777778
# Bagging:  0.3888888888888889
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  48
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.7777777777777778
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  49
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.8333333333333334
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  50
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7777777777777778
# Bagging:  0.4444444444444444
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  51
# Accuracy Cay Quyet Dinh: 0.2777777777777778
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7777777777777778
# Bagging:  0.2777777777777778
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  52
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.6666666666666666
# Accuracy RF:  0.4444444444444444
# Chay Lan thu:  53
# Accuracy Cay Quyet Dinh: 0.3333333333333333
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.4444444444444444
# Accuracy RF:  0.5555555555555556
# Chay Lan thu:  54
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.8333333333333334
# Bagging:  0.5
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  55
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7777777777777778
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  56
# Accuracy Cay Quyet Dinh: 0.7777777777777778
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.3333333333333333
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  57
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  58
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.2777777777777778
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  59
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5
# Bagging:  0.4444444444444444
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  60
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  61
# Accuracy Cay Quyet Dinh: 0.7777777777777778
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.5555555555555556
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  62
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  63
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7777777777777778
# Bagging:  0.4444444444444444
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  64
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.3333333333333333
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  65
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7777777777777778
# Bagging:  0.8333333333333334
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  66
# Accuracy Cay Quyet Dinh: 0.4444444444444444
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7777777777777778
# Bagging:  0.4444444444444444
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  67
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.8333333333333334
# Bagging:  0.6666666666666666
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  68
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.6666666666666666
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  69
# Accuracy Cay Quyet Dinh: 0.8333333333333334
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.4444444444444444
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  70
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.7777777777777778
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  71
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5
# Bagging:  0.7222222222222222
# Accuracy RF:  0.5555555555555556
# Chay Lan thu:  72
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.4444444444444444
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  73
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  74
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.5
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  75
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5
# Bagging:  0.4444444444444444
# Accuracy RF:  0.5
# Chay Lan thu:  76
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  77
# Accuracy Cay Quyet Dinh: 0.8333333333333334
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.5
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  78
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  79
# Accuracy Cay Quyet Dinh: 0.3888888888888889
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  80
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.7777777777777778
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  81
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.6111111111111112
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  82
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.6666666666666666
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  83
# Accuracy Cay Quyet Dinh: 0.4444444444444444
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.5555555555555556
# Accuracy RF:  0.5
# Chay Lan thu:  84
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  85
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.6666666666666666
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  86
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  87
# Accuracy Cay Quyet Dinh: 0.5
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  88
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6666666666666666
# Bagging:  0.6666666666666666
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  89
# Accuracy Cay Quyet Dinh: 0.4444444444444444
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.3333333333333333
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  90
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.6111111111111112
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  91
# Accuracy Cay Quyet Dinh: 0.8888888888888888
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.7222222222222222
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  92
# Accuracy Cay Quyet Dinh: 0.7777777777777778
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7777777777777778
# Bagging:  0.5
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  93
# Accuracy Cay Quyet Dinh: 0.5555555555555556
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.7222222222222222
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  94
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.5
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  95
# Accuracy Cay Quyet Dinh: 0.7222222222222222
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.8333333333333334
# Bagging:  0.5555555555555556
# Accuracy RF:  0.7222222222222222
# Chay Lan thu:  96
# Accuracy Cay Quyet Dinh: 0.3888888888888889
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.5
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  97
# Accuracy Cay Quyet Dinh: 0.6111111111111112
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.6111111111111112
# Bagging:  0.6666666666666666
# Accuracy RF:  0.6666666666666666
# Chay Lan thu:  98
# Accuracy Cay Quyet Dinh: 0.6666666666666666
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.5555555555555556
# Bagging:  0.5555555555555556
# Accuracy RF:  0.6111111111111112
# Chay Lan thu:  99
# Accuracy Cay Quyet Dinh: 0.4444444444444444
# Accuracy SVM: 0.6666666666666666
# Naive Bayes:  0.7222222222222222
# Bagging:  0.5
# Accuracy RF:  0.5555555555555556
# Results
# decision tree
# 0.5983333333333334
# 0.12218560057410333
# SVM
# 0.6666666666666669
# 2.220446049250313e-16
# Naive Bayes
# 0.6472222222222223
# 0.10783360524323152
# Bagging
# 0.5633333333333334
# 0.12298248394801876
# Random forest
# 0.6366666666666667
# 0.07674713973035166
# Time
# 0:00:00.082579
# 0:00:00.052781
# 0:00:00.049386
# 0:00:00.065712
# 0:00:00.138933
